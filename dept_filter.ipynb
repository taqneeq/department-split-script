# %%
import pandas as pd

df=pd.read_csv('taq.csv') #Change name of file to the one you use to filter data should be a .CSV file

df
# Out:
#    Submission ID Respondent ID         Submitted at             Name  \
# 0         xbZ4Gr        2DAYYD   2024-11-01 6:49:46    Laksh Agrawal
# 1         Oq0oy7        dk0GOd   2024-11-01 7:08:29      Tanay Kumar
# 2         60xy1P        rkOeo5   2024-11-01 8:20:08   Renee Punamiya
# 3         YBdvy0        b6eoO7   2024-11-01 8:22:17         Tanishka
# 4         ReLQLd        GQpW6e   2024-11-01 8:50:09  Ashwin Upadhyay
# ..           ...           ...                  ...              ...
# 78        WbZN8Q        gkL20M  2024-11-04 18:22:43        Anay Modi
# 79        RerB6K        vdLGKD  2024-11-04 19:11:12     Shravan Kute
# 80        Q9Exv8        vdLGKD  2024-11-04 19:17:13    Atharva Naik
# 81        MZP588        vdLbxQ   2024-11-05 1:52:18  Maitreyi Garate
# 82        604M7J        5pvaVo   2024-11-05 4:04:26      Aryan Pisal
#
#     Phone Number                         Email       SAP ID    Course  Year  \
# ...

# %%
departments = ["Admin","Logistics","Digital Creatives","Tech & Collab","Hospitality","In-House Creatives",
               "Informals","Events","Workshops","Artist & Guest Management","Marketing","Social Media & Content Writing",
               "Publicity","Photography"]


for i in departments:
    df_dept=df[(df['Department Preference 1']==i)|(df['Department Preference 2']==i)|(df['Department Preference 3']==i)]
    df_dept.to_excel(i+'.xlsx',index=False)
